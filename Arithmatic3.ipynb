# %%
#Addition

n1=int(input("Enter first number"))
n2=int(input("Enter second number"))
add=n1+n2
print("Addition:",add)
# Out:
# Enter first number 289
# Enter second number 387
# Addition: 676

# %%
n1=int(input("Enter first number"))
n2=int(input("Enter second number"))
n3=int(input("Enter third number"))
add=n1+n2+n3
print(f"addition of {n1} ,{n2} and {n3} is: {add}")
# Out:
# Enter first number 152
# Enter second number 498
# Enter third number 289
# addition of 152 ,498 and 289 is: 939

# %%
##Substraction

n1=int(input("Enter first number"))
n2=int(input("Enter second number"))
sub=n1-n2
print("Substraction:",sub)
# Out:
# Enter first number 764
# Enter second number 389
# Substraction: 375

# %%
n1=int(input("Enter first number"))
n2=int(input("Enter second number"))
sub=n1-n2
print(f"Substraction of {n1} and {n2} is: {sub}")
# Out:
# Enter first number 789
# Enter second number 678
# Substraction of 789 and 678 is: 111

# %%
# Multiplication

n1=int(input("Enter first number"))
n2=int(input("Enter second number"))
mult=n1*n2
print("Multiplication:",mult)
# Out:
# Enter first number 90
# Enter second number 133
# Multiplication: 11970

# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
c=int(input("Enter third number"))
mult=a*b*c
print(f"addition of {a} ,{b} and {c} is: {mult}")
# Out:
# Enter first number 23
# Enter second number 10
# Enter third number 7
# addition of 23 ,10 and 7 is: 1610

# %%
# Division

n1=int(input("Enter first number"))
n2=int(input("Enter second number"))
div=n1/n2
print("Division:",div)
# Out:
# Enter first number 456
# Enter second number 78
# Division: 5.846153846153846

# %%
n1=int(input("Enter first number"))
n2=int(input("Enter second number"))
div=n1/n2
print(f"Division of {n1} and {n2} is: {div}")
# Out:
# Enter first number 28635
# Enter second number 125
# Division of 28635 and 125 is: 229.08
