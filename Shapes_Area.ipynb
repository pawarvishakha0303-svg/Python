# %% [markdown]
# # Area of Shapes

# %%
# Square

side=float(input("Enter side of square"))
area=side*side
print("Area of Square=",area)
# Out:
# Enter side of square 5
# Area of Square= 25.0

# %%
# Rectangle

length=float(input("Enter length of rectangle"))
width=float(input("Enter width of rectangle"))
area=length*width
print("Area of Rectangle=",area)
# Out:
# Enter length of rectangle 8
# Enter width of rectangle 6
# Area of Rectangle= 48.0

# %%
# Triangle

base=float(input("Enter base"))
height=float(input("Enter height"))
area=base*height
print("Area of Triangle=",area)
# Out:
# Enter base 5.7
# Enter height 5
# Area of Triangle= 28.5

# %%
# Circle

rad=float(input("Enter radius"))
area=3.14*rad*rad
print("Area of Circle",area)
# Out:
# Enter radius 7.6
# Area of Circle 181.3664

# %%
# Parallelogram

base=float(input("Enter base"))
height=float(input("Enter height"))
area=base*height
print("Area of Parallelogram=",area)
# Out:
# Enter base 4.7
# Enter height 8.5
# Area of Parallelogram= 39.95

# %%
# Rhombus

d1=float(input("Enter first diagonal"))
d2=float(input("Enter second diagonal"))
area=(d1*d2)/2
print("Area of Rhombus=",area)
# Out:
# Enter first diagonal 6
# Enter second diagonal 3
# Area of Rhombus= 9.0
