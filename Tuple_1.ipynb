# %% [markdown]
# # Tuple:
# A tuple is an ordered,immutable collection of elements enclosed in parnthesis().

# %% [markdown]
# # Create a tuple.

# %%
t1=(5,10,15,20,25,30,35,40,45,50)

# %%
num=(1,11,21,31,41,51,61,71,91)

# %%
names=("shreya","neha","trisha","tanvi","megha","sanu","sakshi","jyoti","rutu","mahi")

# %% [markdown]
# # Print a tuple

# %%
t1
# Out:
# (5, 10, 15, 20, 25, 30, 35, 40, 45, 50)

# %%
num
# Out:
# (1, 11, 21, 31, 41, 51, 61, 71, 91)

# %%
names
# Out:
# ('shreya',
#  'neha',
#  'trisha',
#  'tanvi',
#  'megha',
#  'sanu',
#  'sakshi',
#  'jyoti',
#  'rutu',
#  'mahi')

# %% [markdown]
# # Print type of tuple

# %%
print(type(t1))
# Out:
# <class 'tuple'>

# %%
print(type(num))
# Out:
# <class 'tuple'>

# %%
print(type(names))
# Out:
# <class 'tuple'>

# %% [markdown]
# # Access the elements by index value

# %%
t1[5]
# Out:
# 30

# %%
t1[-4]
# Out:
# 35

# %%
num[0]
# Out:
# 1

# %%
num[5]
# Out:
# 51

# %%
num[-2]
# Out:
# 71

# %%
names[8]
# Out:
# 'rutu'

# %%
names[-3]
# Out:
# 'jyoti'

# %% [markdown]
# # tuple slicing

# %%
t1[2:5]
# Out:
# (15, 20, 25)

# %%
t1[5:50]
# Out:
# (30, 35, 40, 45, 50)

# %%
num[2:10]
# Out:
# (21, 31, 41, 51, 61, 71, 91)

# %%
num[0:5]
# Out:
# (1, 11, 21, 31, 41)

# %%
names[2:5]
# Out:
# ('trisha', 'tanvi', 'megha')

# %%
names[2:-5]
# Out:
# ('trisha', 'tanvi', 'megha')
