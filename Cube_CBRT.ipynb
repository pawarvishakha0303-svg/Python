# %% [markdown]
# Cube of number

# %%
num=float(input("Enter a number"))
cube=num**3
print("Cube=",cube)
# Out:
# Enter a number 11
# Cube= 1331.0

# %%
num=float(input("Enter a number"))
cube=num**3
print("Cube=",cube)
# Out:
# Enter a number 4
# Cube= 64.0

# %%
num=float(input("Enter a number"))
cube=num**3
print("Cube=",cube)
# Out:
# Enter a number 8
# Cube= 512.0

# %%
num=float(input("Enter a number"))
cube=num**3
print("Cube=",cube)
# Out:
# Enter a number 15
# Cube= 3375.0

# %%
num=float(input("Enter a number"))
cube=num**3
print("Cube=",cube)
# Out:
# Enter a number 3.3
# Cube= 35.937

# %% [markdown]
# Cube Root of number

# %%
num=int(input("Enter a number"))
cbrt=num ** (1/3)
print(" Cube Root=",cbrt)
# Out:
# Enter a number 125
#  Cube Root= 4.999999999999999

# %%
num=int(input("Enter a number"))
cbrt=num ** (1/3)
print(" Cube Root=",cbrt)
# Out:
# Enter a number 8
#  Cube Root= 2.0

# %%
num=int(input("Enter a number"))
cbrt=num ** (1/3)
print(" Cube Root=",cbrt)
# Out:
# Enter a number 1
#  Cube Root= 1.0

# %%
num=int(input("Enter a number"))
cbrt=num ** (1/3)
print(" Cube Root=",cbrt)
# Out:
# Enter a number 875
#  Cube Root= 9.564655913861944

# %%
num=int(input("Enter a number"))
cbrt=num ** (1/3)
print(" Cube Root=",cbrt)
# Out:
# Enter a number 9054
#  Cube Root= 20.842356979867144
