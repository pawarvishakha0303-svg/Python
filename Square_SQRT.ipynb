# %% [markdown]
# Square of Numbers

# %%
num=float(input("Enter a number:"))
square=num**2
print("Square=",square)
# Out:
# Enter a number: 10
# Square= 100.0

# %%
num1=float(input("Enter a number:"))
square=num1**2
print("Square=",square)
# Out:
# Enter a number: 6.8
# Square= 46.239999999999995

# %%
num2=float(input("Enter a number:"))
square=num2**2
print("Square=",square)
# Out:
# Enter a number: 56
# Square= 3136.0

# %%
num3=float(input("Enter a number:"))
square=num3**2
print("Square=",square)
# Out:
# Enter a number: 143
# Square= 20449.0

# %%
num4=float(input("Enter a number:"))
square=num4**2
print("Square=",square)
# Out:
# Enter a number: 7452
# Square= 55532304.0

# %% [markdown]
# SquareRoot of numbers

# %%
n=float(input("Enter a number"))
sqrt=n**0.5
print("Square Root=",sqrt)
# Out:
# Enter a number 100
# Square Root= 10.0

# %%
n=float(input("Enter a number"))
sqrt=n**0.5
print("Square Root=",sqrt)
# Out:
# Enter a number 235
# Square Root= 15.329709716755891

# %%
n=float(input("Enter a number"))
sqrt=n**0.5
print("Square Root=",sqrt)
# Out:
# Enter a number 57.4
# Square Root= 7.576278769950324

# %%
n=float(input("Enter a number"))
sqrt=n**0.5
print("Square Root=",sqrt)
# Out:
# Enter a number 895
# Square Root= 29.916550603303182

# %%
n=float(input("Enter a number"))
sqrt=n**0.5
print("Square Root=",sqrt)
# Out:
# Enter a number 8633
# Square Root= 92.91393867445294
