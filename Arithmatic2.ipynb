# %%
# Addition
a=34
b=56
c=87
add=a+b+c
add
# Out:
# 177

# %%
n1=345
n2=923
n3=234
n4=99
add=n1+n2+n3+n4
add
# Out:
# 1601

# %%
# Substraction
a=2678
b=1176
c=498
d=200
e=578
sub=a-b-c-d-e
sub
# Out:
# 226

# %%
num1=5098
num2=2000
num3=278
sub=num1-num2-num3
sub
# Out:
# 2820

# %%
# Multiplication
a=34
b=57
c=4
d=123
mult=a*b*c*d
mult
# Out:
# 953496

# %%
n1=2
n2=9
n3=10
mult=n1*n2*n3
mult
# Out:
# 180

# %%
p=98
q=54
r=34
s=0
mult=p*q*r*s
mult
# Out:
# 0

# %%
# Division

a=1000
b=100
c=10
div=a/b/c
div
# Out:
# 1.0

# %%
n1=1200
n2=12
n2=3
n4=4
div=n1/n2/n3/n4
div
# Out:
# 10.0

# %%
a=2345
b=34
div=a/b
div
# Out:
# 68.97058823529412
