# %% [markdown]
# # List Functions:
# len() - Returns the number of elements
#
# max() - Returns the largest element
#
# min() - Returns the smallest element
#
# sum() - Returns the sum of numeric elements
#
# sorted() - Returns a new sorted list

# %%
num=[23,98,45,73,49,89,63,55,19,40,81,60,94,10]

# %%
num
# Out:
# [23, 98, 45, 73, 49, 89, 63, 55, 19, 40, 81, 60, 94, 10]

# %%
# Counts the length of the whole list

len(num)
# Out:
# 14

# %%
# It is used for sorting of the list

sorted(num)
# Out:
# [10, 19, 23, 40, 45, 49, 55, 60, 63, 73, 81, 89, 94, 98]

# %%
# Maximum element
max(num)
# Out:
# 98

# %%
# Minimum element

min(num)
# Out:
# 10

# %%
# Addition of all elements in the list

sum(num)
# Out:
# 799

# %%
dist=["Pune","Satara","Sangli","Kolhapur","Solapur","Nagpur","Dhule","Jalgaon","Ratnagiri"]

# %%
dist
# Out:
# ['Pune',
#  'Satara',
#  'Sangli',
#  'Kolhapur',
#  'Solapur',
#  'Nagpur',
#  'Dhule',
#  'Jalgaon',
#  'Ratnagiri']

# %%
# Counts the length of the whole list

len(dist)
# Out:
# 9

# %%
# It is used for sorting of the list

sorted(dist)
# Out:
# ['Dhule',
#  'Jalgaon',
#  'Kolhapur',
#  'Nagpur',
#  'Pune',
#  'Ratnagiri',
#  'Sangli',
#  'Satara',
#  'Solapur']

# %%
max(dist)
# Out:
# 'Solapur'

# %%
min(dist)
# Out:
# 'Dhule'

# %% [markdown]
# #  list methods:
# append() – Adds a single element to the end of the list.
#
# extend() – Adds multiple elements (from another list or iterable) to the end of the list.
#
# insert() – Inserts an element at a specified position.
#
# remove() – Removes the first occurrence of the specified element.
#
# pop() – Removes and returns the element at the specified index. If no index is given, it removes the last element.
#
# clear() – Removes all elements from the list.
#
# index() – Returns the index (position) of the first occurrence of the specified element.
#
# count() – Returns the number of times an element appears in the list.
#
# sort() – Sorts the list in ascending order by default.
#
# reverse() – Reverses the order of the elements in the list.
#
# copy() – Creates and returns a shallow copy of the list.

# %%
list=[1,4,9,16,25,36,49,64,81,100]

# %%
list
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
# Adding element at end of the list

list.append(121)

# %%
list.append(144)

# %%
list
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144]

# %%
# Adding multiple element at end

list.extend([169,264])

# %%
list
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 264]

# %%
# Insert element at specific position

list.insert(13,196)

# %%
list.insert(14,225)

# %%
list
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 264]

# %%
# Removes element

list.remove(169)

# %%
list
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 196, 225, 264]

# %%
list.pop()
# Out:
# 264

# %%
# How many times number occured in list

list.count(16)
# Out:
# 1

# %%
# Sorting as a ascending or descending order

list.sort()

# %%
list
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 196, 225]

# %%
# Reverse the list

list.reverse()

# %%
list
# Out:
# [225, 196, 144, 121, 100, 81, 64, 49, 36, 25, 16, 9, 4, 1]

# %%
# Copy the whole list and create new list

new_list=list.copy()

# %%
new_list
# Out:
# [225, 196, 144, 121, 100, 81, 64, 49, 36, 25, 16, 9, 4, 1]

# %%
# Clear the list

new_list.clear()

# %%
new_list
# Out:
# []
