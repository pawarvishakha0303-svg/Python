# %%
# Addition 

n1=3
n2=23
add=n1+n2
add
# Out:
# 26

# %%
a=28
b=67
add=a+b
add
# Out:
# 95

# %%
n1=34.67
n2=76.43
add=n1+n2
add
# Out:
# 111.10000000000001

# %%
# Substraction

a=46
b=23
sub=a-b
sub
# Out:
# 23

# %%
n1=57.34
n2=23.54
sub=n1-n2
sub
# Out:
# 33.800000000000004

# %%
a=97
b=45
sub=a-b
sub
# Out:
# 52

# %%
# Multiplication

num1=35
num2=10
mult=num1*num2
mult
# Out:
# 350

# %%
num1=23
num2=89
mult=num1*num2
mult
# Out:
# 2047

# %%
# Division
n1=28
n2=3
div=n1/n2
div
# Out:
# 9.333333333333334

# %%
n1=88
n2=4
div=n1/n2
div
# Out:
# 22.0
