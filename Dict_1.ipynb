# %% [markdown]
# # Dictonary:

# %% [markdown]
# # Create d dictonary

# %%
d={1:'Pune',2:'Satara',3:'Sangli',4:'Kolhapur',5:'Solapur'}

# %%
d1={101:"Jyoti",102:"Sakshi",103:"Shreya",104:"Rutuja",105:"Vaishnavi"}

# %%
num={1:1,2:4,3:9,4:16,5:25}

# %%
stud={"name":"Sneha","age":21,}

# %% [markdown]
# # Print dictonary

# %%
d
# Out:
# {1: 'Pune', 2: 'Satara', 3: 'Sangli', 4: 'Kolhapur', 5: 'Solapur'}

# %%
d1
# Out:
# {101: 'Jyoti', 102: 'Sakshi', 103: 'Shreya', 104: 'Rutuja', 105: 'Vaishnavi'}

# %%
num
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
stud
# Out:
# {'name': 'Sneha', 'age': 21}

# %% [markdown]
# # Print type of dictonary

# %%
print(type(d))
# Out:
# <class 'dict'>

# %%
print(type(d1))
# Out:
# <class 'dict'>

# %%
print(type(num))
# Out:
# <class 'dict'>

# %% [markdown]
# # Access elements by index value
# A dictonary does not support indexing because it is designed to store data as key-value pairs,not as an ordered sequence of elements

# %%
dict[2]
# Out:
# dict[2]

# %% [markdown]
# # Slicing Support
# Dictonary does not support slicing because it is mapping data type,not a sequence

# %%
d[2:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 d[2:2]
#
# NameError: name 'd' is not defined
